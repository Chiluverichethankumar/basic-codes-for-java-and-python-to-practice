# %% [markdown]
# ### Python Data Structures and Boolean
# - Boolean
# - Boolean and Logical Operators
# - Comparison operators
# - List
# - Tuple
# - Set
# - Dictionaries

# %% [markdown]
# #### Boolean Variable
# - True and False

# %%
bool()
# Out:
# False

# %%
True
# Out:
# True

# %%
False
# Out:
# False

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool

# %%
my_str="Chethan Kumar"
my_str.upper()
# Out:
# 'CHETHAN KUMAR'

# %%
my_str.capitalize()
# Out:
# 'Chethan kumar'

# %%
my_str.isalnum()
# Out:
# False

# %%
print(my_str.isalnum())
print(my_str.isalpha())
print(my_str.isdigit())
print(my_str.isupper())
print(my_str.islower())
print(my_str.isspace())
print(my_str.endswith('r'))
print(my_str.startswith('C'))
# Out:
# False
# False
# False
# False
# False
# False
# True
# True

# %% [markdown]
# #### Boolean and Logical Operators

# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
str1="Chethan"
str2="Hello"

# %%
print(str1.isupper() or str2.isalpha())
print(str1.isupper() and str2.isalpha())
print(str1.isalpha() and str2.istitle())
print(str1.isnumeric() or str2.isupper())
print(str1.isupper() or str2.isalpha())
# Out:
# True
# False
# True
# False
# True

# %% [markdown]
# #### List
# - []
# - mutable or changeable , ordered

# %%
List=[]
type(List)
# Out:
# list

# %%
List1=list()
type(List1)
# Out:
# list

# %%
List=["chethan","kumar",100,200,300]
print(type(List))
print(len(List))
# Out:
# <class 'list'>
# 5

# %%
## indexing in list start fr0m 0 , 1, 2, 3, . . . . .
## indexing in list also negative  from  -1, -2, -3, . . . . . state from end 
print(List[0])
print(List[2])
print(List[:])
print(List[2:])
print(List[2:4])
# Out:
# chethan
# 100
# ['chethan', 'kumar', 100, 200, 300, 'Chiluveri', 'Chiluveri']
# [100, 200, 300, 'Chiluveri', 'Chiluveri']
# [100, 200]

# %%
# Append
List.append("Chiluveri")
print(List)
# Insert
